# %% [markdown]
# # Phase 1: Data Acquisition
#
# # Load datasets into Python.

# %% [markdown]
# # Load datset1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dataset1 = pd.read_csv('dataset_1.csv')

# %%
dataset1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1    1/1/2011       1   0     1   0    False        6           1
# 1          2    1/1/2011       1   0     1   1    False        6           1
# 2          3    1/1/2011       1   0     1   2    False        6           1
# 3          4    1/1/2011       1   0     1   3    False        6           1
# 4          5    1/1/2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %% [markdown]
# # data structures using .info() and .head()

# %%
dataset1.head()
# Out:
#    instant    dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp
# 0        1  1/1/2011       1   0     1   0    False        6           1  0.24
# 1        2  1/1/2011       1   0     1   1    False        6           1  0.22
# 2        3  1/1/2011       1   0     1   2    False        6           1  0.22
# 3        4  1/1/2011       1   0     1   3    False        6           1  0.24
# 4        5  1/1/2011       1   0     1   4    False        6           1  0.24

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %% [markdown]
# # turn warning off in a cell jupyter notebook

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # dataset1 Visualize key subplot,distplot,histplot and boxplot

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.distplot(dataset1['holiday'])

plt.subplot(1,2,2)
sns.distplot(dataset1['weekday'])


plt.show()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.distplot(dataset1['weathersit'])

plt.subplot(1,2,2)
sns.distplot(dataset1['temp'])


plt.show()

# %%
sns.histplot(dataset1["holiday"])
# Out:
# <Axes: xlabel='holiday', ylabel='Count'>

# %%
sns.histplot(dataset1["weekday"])
# Out:
# <Axes: xlabel='weekday', ylabel='Count'>

# %%
sns.histplot(dataset1["weathersit"])
# Out:
# <Axes: xlabel='weathersit', ylabel='Count'>

# %%
sns.histplot(dataset1["temp"])
# Out:
# <Axes: xlabel='temp', ylabel='Count'>

# %%
sns.boxplot(dataset1["holiday"])
# Out:
# <Axes: ylabel='holiday'>

# %%
sns.boxplot(dataset1["weekday"])
# Out:
# <Axes: ylabel='weekday'>

# %%
sns.boxplot(dataset1["weathersit"])
# Out:
# <Axes: ylabel='weathersit'>

# %%
sns.boxplot(dataset1["temp"])
# Out:
# <Axes: ylabel='temp'>

# %% [markdown]
# # Load datset2

# %%
dataset2 = pd.read_csv('dataset_2.csv')

# %%
dataset2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %% [markdown]
# # data structures using .info() and .head()

# %%
dataset2.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %% [markdown]
# # dataset2 Visualize key subplot,distplot,histplot and boxplot

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.distplot(dataset2['atemp'])

plt.subplot(1,2,2)
sns.distplot(dataset2['hum'])


plt.show()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.distplot(dataset2['windspeed'])

plt.subplot(1,2,2)
sns.distplot(dataset2['casual'])


plt.show()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.distplot(dataset2['registered'])

plt.subplot(1,2,2)
sns.distplot(dataset2['cnt'])


plt.show()

# %%
sns.histplot(dataset2["atemp"])
# Out:
# <Axes: xlabel='atemp', ylabel='Count'>

# %%
sns.histplot(dataset2["hum"])
# Out:
# <Axes: xlabel='hum', ylabel='Count'>

# %%
sns.histplot(dataset2["windspeed"])
# Out:
# <Axes: xlabel='windspeed', ylabel='Count'>

# %%
sns.histplot(dataset2["casual"])
# Out:
# <Axes: xlabel='casual', ylabel='Count'>

# %%
sns.histplot(dataset2["registered"])
# Out:
# <Axes: xlabel='registered', ylabel='Count'>

# %%
sns.histplot(dataset2["cnt"])
# Out:
# <Axes: xlabel='cnt', ylabel='Count'>

# %%
sns.boxplot(dataset2["atemp"])
# Out:
# <Axes: ylabel='atemp'>

# %%
sns.boxplot(dataset2["hum"])
# Out:
# <Axes: ylabel='hum'>

# %%
sns.boxplot(dataset2["windspeed"])
# Out:
# <Axes: ylabel='windspeed'>

# %%
sns.boxplot(dataset2["casual"])
# Out:
# <Axes: ylabel='casual'>

# %%
sns.boxplot(dataset2["registered"])
# Out:
# <Axes: ylabel='registered'>

# %%
sns.boxplot(dataset2["cnt"])
# Out:
# <Axes: ylabel='cnt'>

# %% [markdown]
# # check null and duplicated values

# %%
dataset1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
dataset1.duplicated().sum()
# Out:
# 0

# %%
dataset2.isnull().sum()
# Out:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
dataset2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Phase 2: Data Wrangling
# # Dataset_1 and Dataset_2 Integration

# %%
data1_and_2 = pd.merge(dataset1,dataset2,on='instant',how ='inner')

# %%
data1_and_2
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1    1/1/2011       1   0     1   0    False        6           1
# 1          2    1/1/2011       1   0     1   1    False        6           1
# 2          3    1/1/2011       1   0     1   2    False        6           1
# 3          4    1/1/2011       1   0     1   3    False        6           1
# 4          5    1/1/2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %% [markdown]
# # Integration data structures using .info() and .head()

# %%
data1_and_2.head()
# Out:
#    instant    dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  1/1/2011       1   0     1   0    False        6           1
# 1        2  1/1/2011       1   0     1   1    False        6           1
# 2        3  1/1/2011       1   0     1   2    False        6           1
# 3        4  1/1/2011       1   0     1   3    False        6           1
# 4        5  1/1/2011       1   0     1   4    False        6           1
#
#    temp  Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24           0  0.2879  0.81        0.0       3          13   16
# 1  0.22           1  0.2727  0.80        0.0       8          32   40
# 2  0.22           2  0.2727  0.80        0.0       5          27   32
# 3  0.24           3  0.2879  0.75        0.0       3          10   13
# 4  0.24           4  0.2879  0.75        0.0       0           1    1

# %%
data1_and_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  Unnamed: 0  610 non-null    int64
#  11  atemp       599 non-null    float64
#  12  hum         610 non-null    float64
#  13  windspeed   610 non-null    float64
#  14  casual      610 non-null    int64
#  15  registered  610 non-null    int64
#  16  cnt         610 non-null    int64
# dtypes: bool(1), float64(4), int64(11), object(1)
# memory usage: 77.0+ KB

# %% [markdown]
# # check null and duplicated values

# %%
data1_and_2.isnull().sum()
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# Unnamed: 0     0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
data1_and_2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Integration data Visualize key subplot,distplot and scatterplot

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(data1_and_2['holiday'])

plt.subplot(2,2,2)
sns.distplot(data1_and_2['weekday'])

plt.subplot(2,2,3)
sns.distplot(data1_and_2['weathersit'])

plt.subplot(2,2,4)
sns.distplot(data1_and_2['temp'])

plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(data1_and_2['atemp'])

plt.subplot(2,2,2)
sns.distplot(data1_and_2['hum'])

plt.subplot(2,2,3)
sns.distplot(data1_and_2['windspeed'])

plt.subplot(2,2,4)
sns.distplot(data1_and_2['casual'])

plt.show()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.distplot(data1_and_2['registered'])

plt.subplot(1,2,2)
sns.distplot(data1_and_2['cnt'])


plt.show()

# %%
sns.scatterplot(data = data1_and_2,x = 'holiday',y = 'weekday')
# Out:
# <Axes: xlabel='holiday', ylabel='weekday'>

# %%
sns.scatterplot(data = data1_and_2,x = 'weathersit',y = 'temp')
# Out:
# <Axes: xlabel='weathersit', ylabel='temp'>

# %%
sns.scatterplot(data = data1_and_2,x = 'atemp',y = 'hum')
# Out:
# <Axes: xlabel='atemp', ylabel='hum'>

# %%
sns.scatterplot(data = data1_and_2,x = 'windspeed',y = 'casual')
# Out:
# <Axes: xlabel='windspeed', ylabel='casual'>

# %%
sns.scatterplot(data = data1_and_2,x = 'registered',y = 'cnt')
# Out:
# <Axes: xlabel='registered', ylabel='cnt'>

# %% [markdown]
# # Task 2 (Week 2): Dataset_3 Integration
#
# # Concatenate Dataset_3 with the merged dataset.

# %% [markdown]
# # Load datset3

# %%
dataset3 = pd.read_csv('dataset_3.csv')

# %%
dataset3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %% [markdown]
# # data structures using .info() and .head()

# %%
dataset3.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %% [markdown]
# # check null and duplicated values

# %%
dataset3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
dataset3.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Integration data Visualize key subplot,distplot and scatterplot

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(dataset3['holiday'])

plt.subplot(2,2,2)
sns.distplot(dataset3['weekday'])

plt.subplot(2,2,3)
sns.distplot(dataset3['weathersit'])

plt.subplot(2,2,4)
sns.distplot(dataset3['temp'])

plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(dataset3['atemp'])

plt.subplot(2,2,2)
sns.distplot(dataset3['hum'])

plt.subplot(2,2,3)
sns.distplot(dataset3['windspeed'])

plt.subplot(2,2,4)
sns.distplot(dataset3['casual'])

plt.show()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.distplot(dataset3['registered'])

plt.subplot(1,2,2)
sns.distplot(dataset3['cnt'])


plt.show()

# %%
sns.scatterplot(data = dataset3,x = 'holiday',y = 'weekday')
# Out:
# <Axes: xlabel='holiday', ylabel='weekday'>

# %%
sns.scatterplot(data = dataset3,x = 'weathersit',y = 'temp')
# Out:
# <Axes: xlabel='weathersit', ylabel='temp'>

# %%
sns.scatterplot(data = dataset3,x = 'atemp',y = 'hum')
# Out:
# <Axes: xlabel='atemp', ylabel='hum'>

# %%
sns.scatterplot(data = dataset3,x = 'windspeed',y = 'casual')
# Out:
# <Axes: xlabel='windspeed', ylabel='casual'>

# %%
sns.scatterplot(data = dataset3,x = 'registered',y = 'cnt')
# Out:
# <Axes: xlabel='registered', ylabel='cnt'>

# %%
merged_df = pd.concat([data1_and_2,dataset3], axis=0, ignore_index=True)

# %%
merged_df
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1    1/1/2011       1   0     1   0    False        6           1
# 1          2    1/1/2011       1   0     1   1    False        6           1
# 2          3    1/1/2011       1   0     1   2    False        6           1
# 3          4    1/1/2011       1   0     1   3    False        6           1
# 4          5    1/1/2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 995      615  28-01-2011       1   0     1  20    False        5           2
# 996      616  28-01-2011       1   0     1  21    False        5           2
# 997      617  28-01-2011       1   0     1  22    False        5           1
# 998      618  28-01-2011       1   0     1  23    False        5           1
# 999      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %% [markdown]
# # data structures using .info() and .head()

# %%
merged_df.head()
# Out:
#    instant    dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  1/1/2011       1   0     1   0    False        6           1
# 1        2  1/1/2011       1   0     1   1    False        6           1
# 2        3  1/1/2011       1   0     1   2    False        6           1
# 3        4  1/1/2011       1   0     1   3    False        6           1
# 4        5  1/1/2011       1   0     1   4    False        6           1
#
#    temp  Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24         0.0  0.2879  0.81        0.0       3          13   16
# 1  0.22         1.0  0.2727  0.80        0.0       8          32   40
# 2  0.22         2.0  0.2727  0.80        0.0       5          27   32
# 3  0.24         3.0  0.2879  0.75        0.0       3          10   13
# 4  0.24         4.0  0.2879  0.75        0.0       0           1    1

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1000 non-null   int64
#  1   dteday      1000 non-null   object
#  2   season      1000 non-null   int64
#  3   yr          1000 non-null   int64
#  4   mnth        1000 non-null   int64
#  5   hr          1000 non-null   int64
#  6   holiday     1000 non-null   bool
#  7   weekday     1000 non-null   int64
#  8   weathersit  1000 non-null   int64
#  9   temp        1000 non-null   float64
#  10  Unnamed: 0  610 non-null    float64
#  11  atemp       989 non-null    float64
#  12  hum         1000 non-null   float64
#  13  windspeed   1000 non-null   float64
#  14  casual      1000 non-null   int64
#  15  registered  1000 non-null   int64
#  16  cnt         1000 non-null   int64
# dtypes: bool(1), float64(5), int64(10), object(1)
# memory usage: 126.1+ KB

# %% [markdown]
# # check null and duplicated values

# %%
merged_df.isnull().sum()
# Out:
# instant         0
# dteday          0
# season          0
# yr              0
# mnth            0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# temp            0
# Unnamed: 0    390
# atemp          11
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %%
merged_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Handle missing values

# %%
bfill = merged_df.fillna(method='bfill')

# %%
bfill.isnull().sum()
# Out:
# instant         0
# dteday          0
# season          0
# yr              0
# mnth            0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# temp            0
# Unnamed: 0    390
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %% [markdown]
# # Identify and drop unnecessary columns

# %%
df = merged_df.drop(columns=['Unnamed: 0','yr','mnth'])

# %%
df
# Out:
#      instant      dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0          1    1/1/2011       1   0    False        6           1  0.24
# 1          2    1/1/2011       1   1    False        6           1  0.22
# 2          3    1/1/2011       1   2    False        6           1  0.22
# 3          4    1/1/2011       1   3    False        6           1  0.24
# 4          5    1/1/2011       1   4    False        6           1  0.24
# ..       ...         ...     ...  ..      ...      ...         ...   ...
# 995      615  28-01-2011       1  20    False        5           2  0.24
# 996      616  28-01-2011       1  21    False        5           2  0.22
# 997      617  28-01-2011       1  22    False        5           1  0.24
# 998      618  28-01-2011       1  23    False        5           1  0.24
# 999      619  29-01-2011       1   0    False        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
df.to_csv('merged_file.csv', index=False)

# %% [markdown]
# # Integration data Visualize key subplot,distplot,scatterplot,boxplot,histplot and pieplot

# %%
df = pd.DataFrame({"instant": ["holiday","weekday","temp","weathersit","atemp"]})
df["instant"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df = pd.DataFrame({"instant": ["hum","windspeed","casual","registered","cnt"]})
df["instant"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(merged_df['holiday'])

plt.subplot(2,2,2)
sns.distplot(merged_df['weekday'])

plt.subplot(2,2,3)
sns.distplot(merged_df['weathersit'])

plt.subplot(2,2,4)
sns.distplot(merged_df['temp'])

plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(merged_df['atemp'])

plt.subplot(2,2,2)
sns.distplot(merged_df['hum'])

plt.subplot(2,2,3)
sns.distplot(merged_df['windspeed'])

plt.subplot(2,2,4)
sns.distplot(merged_df['casual'])

plt.show()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.distplot(merged_df['registered'])

plt.subplot(1,2,2)
sns.distplot(merged_df['cnt'])


plt.show()

# %%
sns.boxplot(merged_df["holiday"])
# Out:
# <Axes: ylabel='holiday'>

# %%
sns.boxplot(merged_df["weekday"])
# Out:
# <Axes: ylabel='weekday'>

# %%
sns.boxplot(merged_df["weathersit"])
# Out:
# <Axes: ylabel='weathersit'>

# %%
sns.boxplot(merged_df["temp"])
# Out:
# <Axes: ylabel='temp'>

# %%
sns.boxplot(merged_df["atemp"])
# Out:
# <Axes: ylabel='atemp'>

# %%
sns.boxplot(merged_df["hum"])
# Out:
# <Axes: ylabel='hum'>

# %%
sns.boxplot(merged_df["windspeed"])
# Out:
# <Axes: ylabel='windspeed'>

# %%
sns.boxplot(merged_df["casual"])
# Out:
# <Axes: ylabel='casual'>

# %%
sns.boxplot(merged_df["registered"])
# Out:
# <Axes: ylabel='registered'>

# %%
sns.boxplot(merged_df["cnt"])
# Out:
# <Axes: ylabel='cnt'>

# %%
sns.scatterplot(data = merged_df,x = 'holiday',y = 'weekday')
# Out:
# <Axes: xlabel='holiday', ylabel='weekday'>

# %%
sns.scatterplot(data = merged_df,x = 'weathersit',y = 'temp')
# Out:
# <Axes: xlabel='weathersit', ylabel='temp'>

# %%
sns.scatterplot(data = merged_df,x = 'atemp',y = 'hum')
# Out:
# <Axes: xlabel='atemp', ylabel='hum'>

# %%
sns.scatterplot(data = merged_df,x = 'windspeed',y = 'casual')
# Out:
# <Axes: xlabel='windspeed', ylabel='casual'>

# %%
sns.scatterplot(data = merged_df,x = 'registered',y = 'cnt')
# Out:
# <Axes: xlabel='registered', ylabel='cnt'>

# %%
sns.histplot(merged_df["holiday"])
# Out:
# <Axes: xlabel='holiday', ylabel='Count'>

# %%
sns.histplot(merged_df["weekday"])
# Out:
# <Axes: xlabel='weekday', ylabel='Count'>

# %%
sns.histplot(merged_df["weathersit"])
# Out:
# <Axes: xlabel='weathersit', ylabel='Count'>

# %%
sns.histplot(merged_df["temp"])
# Out:
# <Axes: xlabel='temp', ylabel='Count'>

# %%
sns.histplot(merged_df["atemp"])
# Out:
# <Axes: xlabel='atemp', ylabel='Count'>

# %%
sns.histplot(merged_df["hum"])
# Out:
# <Axes: xlabel='hum', ylabel='Count'>

# %%
sns.histplot(merged_df["windspeed"])
# Out:
# <Axes: xlabel='windspeed', ylabel='Count'>

# %%
sns.histplot(merged_df["casual"])
# Out:
# <Axes: xlabel='casual', ylabel='Count'>

# %%
sns.histplot(merged_df["registered"])
# Out:
# <Axes: xlabel='registered', ylabel='Count'>

# %%
sns.histplot(merged_df["cnt"])
# Out:
# <Axes: xlabel='cnt', ylabel='Count'>
